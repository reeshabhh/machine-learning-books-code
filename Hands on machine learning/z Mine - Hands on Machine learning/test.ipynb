# %%
# !pip install ipympl

# %%
# %pip install --upgrade ipympl

# %%
# !pip install ipywidgets

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %%
x = np.random.normal(size=(3, 5))

# %%
x
# Out:
# array([[ 0.36609038,  0.52005269,  1.39810138, -0.03450371,  0.07138884],
#        [ 1.65797565,  0.31087331,  0.20863727, -0.70964903, -1.14778101],
#        [-0.94520189, -0.87595894, -0.63371363,  0.61908616,  0.56765414]])

# %%
# import IPython

# %%
# %matplotlib inline

# %%
# %matplotlib ipympl

# %%
# %matplotlib widget

# %%
# %matplotlib notebook

# %%
plt.plot(x)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
